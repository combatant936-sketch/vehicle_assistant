# %%
from pydantic import BaseModel, Field
from typing import List

class VehicleIssue(BaseModel):
    id: str = Field(description="Unique identifier, e.g. 'p0420-001'")
    issue_name: str = Field(description="Name of the issue, e.g. 'Catalyst System Efficiency Below Threshold'")
    obd_code: str = Field(description="Real OBD-II code, e.g. 'P0420', 'P0300'. Use 'N/A' if not code-based")
    system: str = Field(description="Engine, Transmission, Brakes, Electrical, Suspension, Cooling, etc.")
    component: str = Field(description="Specific part, e.g. 'Catalytic Converter', 'Brake Pads', 'Alternator'")
    severity: str = Field(description="Low, Medium, High, Critical")
    symptoms: str = Field(description="Comma-separated list, e.g. 'Check engine light, rough idle, reduced power'")
    likely_causes: str = Field(description="Comma-separated list, e.g. 'Faulty O2 sensor, worn spark plugs'")
    diagnostic_steps: str = Field(description="Step-by-step instructions to confirm the diagnosis")
    diy_or_mechanic: str = Field(description="DIY, Mechanic Recommended, Mechanic Required")

class VehicleIssueDataset(BaseModel):
    issues: List[VehicleIssue]

# %%
from openai import OpenAI
import pandas as pd
from dotenv import load_dotenv
load_dotenv()

import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

prompt = """
Generate a dataset of 50 diverse, realistic vehicle issues based on actual OBD-II diagnostic trouble codes and common real-world car problems.
Cover different systems (engine, transmission, brakes, electrical, suspension, cooling).
Use real, verifiable OBD-II codes (e.g. P0171, P0300, P0420, P0455) where applicable, and leave obd_code as 'N/A' for non-code issues like brake wear or suspension noise.
Vary severity levels and mix DIY-fixable issues with ones that require a mechanic.
""".strip()

response = openai_client.responses.parse(
    model='openai/gpt-oss-120b',
    input=[{"role": "user", "content": prompt}],
    text_format=VehicleIssueDataset,
)

dataset = response.output_parsed
df = pd.DataFrame([issue.model_dump() for issue in dataset.issues])
df.to_csv("data/data.csv", index=False)
print(f"Generated {len(df)} vehicle issues")
# Out:
# Generated 16 vehicle issues

# %%
import pandas as pd
from minsearch import Index

df = pd.read_csv("data/data.csv")
documents = df.to_dict(orient="records")

index = Index(
    text_fields=[
        "issue_name",
        "system",
        "component",
        "symptoms",
        "likely_causes",
        "diagnostic_steps",
    ],
    keyword_fields=["id"]
)

index.fit(documents)

# %%
def search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
prompt_template = """
You're a vehicle diagnostic assistant. Answer the QUESTION based on the CONTEXT from our vehicle issues database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()

entry_template = """
issue_name: {issue_name}
obd_code: {obd_code}
system: {system}
component: {component}
severity: {severity}
symptoms: {symptoms}
likely_causes: {likely_causes}
diagnostic_steps: {diagnostic_steps}
diy_or_mechanic: {diy_or_mechanic}
""".strip()

def build_prompt(query, search_results):
    context = ""

    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
from openai import OpenAI

def llm(prompt, model='openai/gpt-oss-120b'):
    response = openai_client.responses.create(
        model=model,
        input=[{"role": "user", "content": prompt}]
    )

    return response.output_text

# %%
def rag(query, model='openai/gpt-oss-120b'):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt, model=model)
    return answer

# %%
question = "Is a P0420 code related to the catalytic converter, and can I fix it myself?"
answer = rag(question)
print(answer)
# Out:
# **Yes.** The P0420 code is for “Catalyst System Efficiency Below Threshold (Bank 1)” and its component is the **catalytic converter**.
#
# **Can you fix it yourself?**
# The database lists the DIY/Mechanic recommendation for this issue as **“Mechanic Recommended.”** That means it’s generally not a safe or reliable DIY repair; you should have a qualified mechanic diagnose and address the problem.

# %%
prompt1_template = """
You are a vehicle diagnostic expert generating evaluation questions.
For the issue below, generate 2 questions that a user might ask.
Return the result as a JSON array with objects containing 'id' and 'question' fields.
Issue: {issue_name}
OBD Code: {obd_code}
System: {system}
Component: {component}
Symptoms: {symptoms}
Likely causes: {likely_causes}
Diagnostic steps: {diagnostic_steps}
""".strip()
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

from tqdm.auto import tqdm
import json

df = pd.read_csv("data/data.csv")

results = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    prompt = prompt1_template.format(**row.to_dict())
    response = openai_client.chat.completions.create(
        model="openai/gpt-oss-120b",
        messages=[{"role": "user", "content": prompt}]
    )
    print(repr(response.choices[0].message.content))
    content = response.choices[0].message.content.strip()

    # strip markdown code fences if the model added them
    if content.startswith("```"):
        content = content.strip("`")
        if content.startswith("json"):
            content = content[4:].strip()

    try:
        questions = json.loads(content)
    except json.JSONDecodeError:
        print(f"Failed to parse id={row['id']}: {content[:200]}")
        continue

    for q in questions:
        q["id"] = row["id"]
        results.append(q)
    for q in questions:
        q["id"] = row["id"]
        results.append(q)

df_questions = pd.DataFrame(results)
df_questions.to_csv("data/ground-truth-retrieval.csv", index=False)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# '[\n  {\n    "id": "1",\n    "question": "What are the steps to clean a dirty Mass Air Flow (MAF) sensor that’s causing a P0171 code?"\n  },\n  {\n    "id": "2",\n    "question": "How can I tell if a vacuum leak is the reason for the ‘System Too Lean (Bank 1)’ error and rough idle?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "What are the steps to diagnose and fix a P0300 random/multiple cylinder misfire, and how do I know if the spark plugs or ignition coils are the culprit?"\n  },\n  {\n    "id": 2,\n    "question": "Can a leaking fuel injector cause a P0300 code, and what tests should I run to determine if the injector needs cleaning or replacement?"\n  }\n]'
# '[\n  {\n    "id": "1",\n    "question": "What are the common reasons for a P0420 code and how can I confirm if my catalytic converter is the problem?"\n  },\n  {\n    "id": "2",\n    "question": "How do I test the upstream O2 sensor and check for exhaust leaks to troubleshoot reduced fuel economy and the check engine light?"\n  }\n]'
# '```json\n[\n  {\n    "id": "1",\n    "question": "Could a loose or faulty fuel cap be the only reason for the P0455 code, and how can I confirm it?"\n  },\n  {\n    "id": "2",\n    "question": "What does a smoke test involve for the EVAP system, and can I perform it at home or do I need a professional?"\n  }\n]\n```'
# '[\n  {\n    "id": "Q1",\n    "question": "How can I test the heater circuit for the Bank 1 oxygen sensor to see if the fuse or wiring is the problem?"\n  },\n  {\n    "id": "Q2",\n    "question": "If the O2 sensor heater is faulty, what is the typical replacement cost and does it affect fuel economy significantly?"\n  }\n]'
# '[\n  {\n    "id": "1",\n    "question": "What are the steps to test the Intake Air Temperature (IAT) sensor and determine if it is causing the P0113 code?"\n  },\n  {\n    "id": "2",\n    "question": "Could a damaged wiring harness or loose connector be responsible for the high input reading on the IAT sensor, and how can I inspect it?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "Why is my check engine light on with code P0128 even though the coolant level looks fine?"\n  },\n  {\n    "id": 2,\n    "question": "What steps should I take to test if my thermostat is stuck open and causing the engine to run cold?"\n  }\n]'
# '[\n  {\n    "id": "Q1",\n    "question": "How can I test the vehicle speed sensor signal with an oscilloscope to confirm if it’s causing the P0500 code?"\n  },\n  {\n    "id": "Q2",\n    "question": "What are the common wiring or connector problems that could lead to erratic speedometer readings and transmission shifting issues for a P0500 fault?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "What does a P0700 code indicate and why is my transmission warning light flashing?"\n  },\n  {\n    "id": 2,\n    "question": "How can I determine if the erratic shifting is caused by a faulty TCM, a wiring problem, or an internal transmission issue?"\n  }\n]'
# '[\n  {\n    "id": "Q1",\n    "question": "What is the proper procedure to test the transmission range sensor output for a P0705 code using a multimeter?"\n  },\n  {\n    "id": "Q2",\n    "question": "Could a wiring short or bad connector cause the P0705 transmission range sensor circuit malfunction, and how can I inspect them?"\n  }\n]'
# '```json\n[\n  {\n    "id": 1,\n    "question": "What are the step‑by‑step procedures to test the throttle body motor resistance for a P2101 code?"\n  },\n  {\n    "id": 2,\n    "question": "Can a dirty throttle body cause the rough idle and throttle lag symptoms associated with P2101, and how do I clean it properly?"\n  }\n]\n```'
# '[\n  {\n    "id": 1,\n    "question": "What does the P2210 code mean and why is my engine running rich on Bank 1?"\n  },\n  {\n    "id": 2,\n    "question": "How can I perform an injector balance test and check fuel pressure to diagnose a leaking injector?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "What does the P0A8C code mean and how does a faulty hybrid battery pack temperature sensor affect my vehicle’s performance?"\n  },\n  {\n    "id": 2,\n    "question": "How can I test the hybrid battery pack temperature sensor and its wiring to determine if it needs to be replaced?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "How can I check the thickness of my brake pads and know when they need to be replaced?"\n  },\n  {\n    "id": 2,\n    "question": "Is the squealing noise and longer stopping distance definitely caused by worn brake pads, or could something else be the problem?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "How can I determine if my brake rotors are warped or have excessive runout?"\n  },\n  {\n    "id": 2,\n    "question": "What is the maximum allowable rotor runout and can I machine the rotors myself or do I need to replace them?"\n  }\n]'
# '[\n  {\n    "id": 1,\n    "question": "How can I perform a pressure test on the ABS hydraulic pump to determine if it\'s the cause of the warning light?"\n  },\n  {\n    "id": 2,\n    "question": "What is involved in replacing a failed ABS pump, and what should I expect in terms of cost and labor?"\n  }\n]'

# %%
import pandas as pd
from tqdm.auto import tqdm

df_question = pd.read_csv("data/ground-truth-retrieval.csv")
ground_truth = df_question.to_dict(orient="records")

# %%
def hit_rate(relevance_total):
    cnt = 0
    for line in relevance_total:
        if True in line:
            cnt += 1
    return cnt / len(relevance_total)

def mrr(relevance_total):
    total_score = 0.0
    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank]:
                total_score += 1 / (rank + 1)
                break
    return total_score / len(relevance_total)

def evaluate(ground_truth, search_function):
    relevance_total = []
    for q in tqdm(ground_truth):
        doc_id = q["id"]
        results = search_function(q)
        relevance = [d["id"] == doc_id for d in results]
        relevance_total.append(relevance)
    return {
        "hit_rate": hit_rate(relevance_total),
        "mrr": mrr(relevance_total)
    }

# %%
evaluate(ground_truth, lambda q: search(q["question"]))
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# {'hit_rate': 1.0, 'mrr': 0.9322916666666666}

# %%
df_validation = df_question[:32]
df_test = df_question[32:]

gt_val = df_validation.to_dict(orient="records")
gt_test = df_test.to_dict(orient="records")

# %%
print(len(df_test))
# Out:
# 32

# %%
def minsearch_search(query, boost=None):
    if boost is None:
        boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )
    return results

# %%
import random

def simple_optimize(param_ranges, objective_function, n_iterations=10):
    best_params = None
    best_score = float("-inf")

    for _ in range(n_iterations):
        current_params = {}
        for field, (low, high) in param_ranges.items():
            current_params[field] = random.uniform(low, high)

        current_score = objective_function(current_params)

        if current_score > best_score:
            best_score = current_score
            best_params = current_params

    return best_params

param_ranges = {
    "issue_name": (0.0, 3.0),
    "obd_code": (0.0, 3.0),
    "system": (0.0, 3.0),
    "component": (0.0, 3.0),
    "severity": (0.0, 3.0),
    "symptoms": (0.0, 3.0),
    "likely_causes": (0.0, 3.0),
    "diagnostic_steps": (0.0, 3.0),
    "diy_or_mechanic": (0.0, 3.0),
}
def objective(boost_params):
    def search_function(q):
        return minsearch_search(q["question"], boost=boost_params)

    results = evaluate(gt_val, search_function)
    return results["hit_rate"]

best_params = simple_optimize(param_ranges, objective, n_iterations=20)
print("Best boost parameters:", best_params)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# Best boost parameters: {'issue_name': 2.3202416062705007, 'obd_code': 2.618567144281709, 'system': 0.14513049578638815, 'component': 0.7607975061336351, 'severity': 2.987567886034243, 'symptoms': 1.6778639196286658, 'likely_causes': 0.022704702373440133, 'diagnostic_steps': 1.968304426805405, 'diy_or_mechanic': 2.1777607455653696}

# %%
def search(query):
    boost = {
        "issue_name": 2.3202416062705007,
        "obd_code": 2.618567144281709,
        "system": 0.14513049578638815,
        "component": 0.7607975061336351,
        "severity": 2.987567886034243,
        "symptoms": 1.6778639196286658,
        "likely_causes": 0.022704702373440133,
        "diagnostic_steps": 1.968304426805405,
        "diy_or_mechanic": 2.1777607455653696
    }


    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
evaluate(gt_test, lambda q: search(q["question"]))
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# {'hit_rate': 1.0, 'mrr': 1.0}

# %%
prompt2_template = """
You are an expert evaluator for a RAG system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as 'NON_RELEVANT', 'PARTLY_RELEVANT', or 'RELEVANT'.

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
import json
from tqdm.auto import tqdm

df_sample = df_question.sample(n=10, random_state=1)
sample = df_sample.to_dict(orient="records")

evaluations = []

for record in tqdm(sample):
    question = record["question"]
    answer_llm = rag(question)

    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)
    evaluation = json.loads(evaluation)

    evaluations.append((record, answer_llm, evaluation))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
df_eval = pd.DataFrame(evaluations, columns=["record", "answer", "evaluation"])

df_eval["id"] = df_eval.record.apply(lambda d: d["id"])
df_eval["question"] = df_eval.record.apply(lambda d: d["question"])
df_eval["relevance"] = df_eval.evaluation.apply(lambda d: d["Relevance"])
df_eval["explanation"] = df_eval.evaluation.apply(lambda d: d["Explanation"])

df_eval.relevance.value_counts(normalize=True)
# Out:
# relevance
# RELEVANT           0.9
# PARTLY_RELEVANT    0.1
# Name: proportion, dtype: float64

# %%
df_eval.to_csv("data/rag-eval-grok-openai/gpt-oss-120b.csv", index=False)
